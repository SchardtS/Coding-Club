# %%
import numpy as np
import matplotlib.pyplot as plt
from functions import *

# %% [markdown]
# ### Polynomial function

# %%
f = lambda x: x**4 - 10*x**2 + 4
df = lambda x: 4*x**3 - 20*x

x0 = np.array([-3, 3, 1, -1])
x_sol = np.empty(x0.shape)
for i in range(x0.shape[0]):
    x_sol[i] = Newton(f, df, x0[i], 1e-6, 100)
    print('Found roots:', x_sol, '\n')
# Out:
# k = 0 x = -3.1041666666666665 f(x) = 0.4911116611810371
# k = 1 x = -3.095634766134307 f(x) = 0.003472914235032931
# k = 2 x = -3.095573567913525 f(x) = 1.7788670447771437e-07
# Found roots: [ -3.09557357 246.98222222  32.125      260.98222222]
#
# k = 0 x = 3.1041666666666665 f(x) = 0.4911116611810371
# k = 1 x = 3.095634766134307 f(x) = 0.003472914235032931
# k = 2 x = 3.095573567913525 f(x) = 1.7788670447771437e-07
# Found roots: [ -3.09557357   3.09557357  32.125      260.98222222]
#
# k = 0 x = 0.6875 f(x) = -0.5031585693359375
# k = 1 x = 0.6470862910816535 f(x) = -0.011879683159127907
# k = 2 x = 0.6460844567859589 f(x) = -7.517772015575019e-06
# k = 3 x = 0.6460838219956366 f(x) = -3.0198066269804258e-12
# Found roots: [ -3.09557357   3.09557357   0.64608382 260.98222222]
#
# k = 0 x = -0.6875 f(x) = -0.5031585693359375
# k = 1 x = -0.6470862910816535 f(x) = -0.011879683159127907
# k = 2 x = -0.6460844567859589 f(x) = -7.517772015575019e-06
# k = 3 x = -0.6460838219956366 f(x) = -3.0198066269804258e-12
# Found roots: [-3.09557357  3.09557357  0.64608382 -0.64608382]

# %%
x = np.linspace(-4, 4, 100)
plt.plot(x, f(x), lw=2)
plt.axhline(0, color='black', lw=1)
plt.scatter(x_sol, f(x_sol), color='red', s=50, zorder=3)

# %% [markdown]
# ### Exponential function

# %%
f = lambda x: np.exp(-x**2) + x/10
df = lambda x: -2*x*np.exp(-x**2) + 1/10

x0 = -1
x_sol = Newton(f, df, x0, 1e-6, 100)
print('Found root:', x_sol, '\n')
# Out:
# k = 0 x = -1.3205223980635363 f(x) = 0.04280605032334042
# k = 1 x = -1.3967156995901358 f(x) = 0.0024866316791994636
# k = 2 x = -1.4017178837353865 f(x) = 1.030625741807456e-05
# k = 3 x = -1.4017387892833704 f(x) = 1.7948376118681608e-10
# Found root: -1.4017387892833704

# %%
x = np.linspace(-4, 4, 100)
plt.plot(x, f(x), lw=2)
plt.axhline(0, color='black', lw=2)
plt.scatter(x_sol, f(x_sol), color='red', s=50, zorder=3)

# %% [markdown]
# ### Complex function

# %%
f = lambda x: x**5 + 1
df = lambda x: 5*x**4

x0 = np.array([-1, 1+0.5j, 1-0.5j, -0.5+1j, -0.5-1j])
x_sol = np.empty(x0.shape, dtype=complex)
for i in range(len(x0)):
    x_sol[i] = Newton(f, df, x0[i], 1e-6, 100)
    print('Found root:', x_sol[i], '\n')
# Out:
# k = 0 x = (-1+0j) f(x) = 0j
# Found root: (-1+0j)
#
# k = 0 x = (0.83584+0.52288j) f(x) = (0.1238343938533456+0.3163861481929513j)
# k = 1 x = (0.7993298117075289+0.5848413768997748j) f(x) = (0.04703725849159224-0.015936557701663023j)
# k = 2 x = (0.8092257848626263+0.5877758527213045j) f(x) = (-0.0008170476862310316+0.0006520678811146596j)
# k = 3 x = (0.8090170601469776+0.5877851948341478j) f(x) = (-9.718760107801927e-08+4.257229881399205e-07j)
# Found root: (0.8090170601469776+0.5877851948341478j)
#
# k = 0 x = (0.83584-0.52288j) f(x) = (0.1238343938533456-0.3163861481929513j)
# k = 1 x = (0.7993298117075289-0.5848413768997748j) f(x) = (0.04703725849159224+0.015936557701663023j)
# k = 2 x = (0.8092257848626263-0.5877758527213045j) f(x) = (-0.0008170476862310316-0.0006520678811146596j)
# k = 3 x = (0.8090170601469776-0.5877851948341478j) f(x) = (-9.718760107801927e-08-4.257229881399205e-07j)
# Found root: (0.8090170601469776-0.5877851948341478j)
#
# k = 0 x = (-0.36416000000000004+0.92288j) f(x) = (0.08408526728732002-0.29175430839888084j)
# k = 1 x = (-0.30524225876171407+0.9442571725002631j) f(x) = (0.037608552756560054+0.00721963521210045j)
# k = 2 x = (-0.3090963537170063+0.9511502682826322j) f(x) = (-0.0005685417476219978-0.00023262706549731504j)
# k = 3 x = (-0.30901702113152446+0.9510565302301099j) f(x) = (-1.0760584046032307e-07-1.0570440217572141e-07j)
# Found root: (-0.30901702113152446+0.9510565302301099j)
#
# k = 0 x = (-0.36416000000000004-0.92288j) f(x) = (0.08408526728732002+0.29175430839888084j)
# k = 1 x = (-0.30524225876171407-0.9442571725002631j) f(x) = (0.037608552756560054-0.00721963521210045j)
# k = 2 x = (-0.3090963537170063-0.9511502682826322j) f(x) = (-0.0005685417476219978+0.00023262706549731504j)
# k = 3 x = (-0.30901702113152446-0.9510565302301099j) f(x) = (-1.0760584046032307e-07+1.0570440217572141e-07j)
# Found root: (-0.30901702113152446-0.9510565302301099j)

# %%
x = np.linspace(-2, 2, 500)
y = np.linspace(-2, 2, 500)
Z = x[None,:] + 1j*y[:,None]

#plt.contourf(x, y, np.abs(f(Z)), 100)
plt.contourf(x, y, np.exp(-np.abs(f(Z))**2), 100)
plt.scatter(x_sol.real, x_sol.imag, color='red')
plt.colorbar()

# %% [markdown]
# ### Two dimensions

# %%
f = lambda x: np.array([np.exp(-x[0]**2 - x[1]**2) - 1/2*x[1], x[0]**2 - x[1]])
df = lambda x: np.array([[-2*x[0]*np.exp(-x[0]**2 - x[1]**2), -2*x[1]*np.exp(-x[0]**2 - x[1]**2) - 1/2],
                         [2*x[0], -1]])

x0 = np.array([[1,1],
               [-1,1]])
x_sol = np.empty(x0.shape)
for i in range(x0.shape[0]):
    x_sol[i,:] = Newton(f, df, x0[i,:], 1e-6, 100)
    print('Found root:', x_sol[i,:], '\n')
# Out:
# k = 0 x = [0.79875146 0.59750291] f(x) = [0.07096695 0.04050098]
# k = 1 x = [0.81441718 0.66302993] f(x) = [0.0003975  0.00024541]
# k = 2 x = [0.81449767 0.66340645] f(x) = [1.67628956e-08 6.47874043e-09]
# Found root: [0.81449767 0.66340645]
#
# k = 0 x = [-0.79875146  0.59750291] f(x) = [0.07096695 0.04050098]
# k = 1 x = [-0.81441718  0.66302993] f(x) = [0.0003975  0.00024541]
# k = 2 x = [-0.81449767  0.66340645] f(x) = [1.67628956e-08 6.47874043e-09]
# Found root: [-0.81449767  0.66340645]

# %%
x = np.linspace(-1.5, 1.5, 1000)
y = np.linspace(-0.75, 2.25, 1000)

X, Y = np.meshgrid(x, y)
Z = f(np.array([X, Y]))

plt.figure()

plt.contourf(x, y, np.linalg.norm(Z, axis=0), 100, cmap='coolwarm')
plt.streamplot(X, Y, Z[0], Z[1], density=2, linewidth = np.sqrt(Z[0]**2 + Z[1]**2), color='black')
plt.scatter(x_sol[:,0], x_sol[:,1], color='red', zorder=3)

# %%
x = np.linspace(-1.5, 1.5, 30)
y = np.linspace(-0.75, 2.25, 30)

X, Y = np.meshgrid(x, y)
Z = f(np.array([X, Y]))

plt.figure()
plt.contourf(x, y, np.linalg.norm(Z, axis=0), 100, cmap='coolwarm')
plt.quiver(X, Y, Z[0], Z[1], color='black', scale=30)
plt.scatter(x_sol[:,0], x_sol[:,1], color='red', zorder=3)
