# %%
library(tidyverse)
library(visdat)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
bob_ross <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2023/2023-02-21/bob_ross.csv')
# Out:
# Rows: 403 Columns: 27
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): img_src, painting_title, youtube_src, colors, color_hex
# dbl  (4): painting_index, season, episode, num_colors
# lgl (18): Black_Gesso, Bright_Red, Burnt_Umber, Cadmium_Yellow, Dark_Sienna,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
theme_set(theme_light())
options(repr.plot.res = 220)

# %%
vis_dat(bob_ross)
# Out:
# plot without title

# %%
bob_ross %>% head
# Out:
#   painting_index img_src
# 1 282            https://www.twoinchbrush.com/images/painting282.png
# 2 283            https://www.twoinchbrush.com/images/painting283.png
# 3 284            https://www.twoinchbrush.com/images/painting284.png
# 4 285            https://www.twoinchbrush.com/images/painting285.png
# 5 286            https://www.twoinchbrush.com/images/painting286.png
# 6 287            https://www.twoinchbrush.com/images/painting287.png
#   painting_title      season episode num_colors
# 1 A Walk in the Woods 1      1       8
# 2 Mt. McKinley        1      2       8
# 3 Ebony Sunset        1      3       9
# 4 Winter Mist         1      4       3
# 5 Quiet Stream        1      5       8
# 6 Winter Moon         1      6       4
#   youtube_src
# 1 https://www.youtube.com/embed/oh5p5f5_-7A
# 2 https://www.youtube.com/embed/RInDWhYceLU
# 3 https://www.youtube.com/embed/UOziR7PoVco
# 4 https://www.youtube.com/embed/0pwoixRikn4
# 5 https://www.youtube.com/embed/DFSIQNjKRfk
# ...

# %%
13*31
# Out:
# [1] 403

# %%
nrow(bob_ross)
# Out:
# [1] 403

# %%
bob_ross %>% count(season)
# Out:
#    season n
# 1   1     13
# 2   2     13
# 3   3     13
# 4   4     13
# 5   5     13
# 6   6     13
# 7   7     13
# 8   8     13
# 9   9     13
# 10 10     13
# 11 11     13
# 12 12     13
# 13 13     13
# 14 14     13
# 15 15     13
# 16 16     13
# 17 17     13
# 18 18     13
# 19 19     13
# 20 20     13
# 21 21     13
# 22 22     13
# 23 23     13
# 24 24     13
# 25 25     13
# 26 26     13
# 27 27     13
# 28 28     13
# 29 29     13
# 30 30     13
# 31 31     13

# %%
bob_ross %>% count(season, episode) %>% filter(n > 1)
# Out:
#      season episode n

# %%
colnames(bob_ross)
# Out:
#  [1] "painting_index"   "img_src"          "painting_title"   "season"
#  [5] "episode"          "num_colors"       "youtube_src"      "colors"
#  [9] "color_hex"        "Black_Gesso"      "Bright_Red"       "Burnt_Umber"
# [13] "Cadmium_Yellow"   "Dark_Sienna"      "Indian_Red"       "Indian_Yellow"
# [17] "Liquid_Black"     "Liquid_Clear"     "Midnight_Black"   "Phthalo_Blue"
# [21] "Phthalo_Green"    "Prussian_Blue"    "Sap_Green"        "Titanium_White"
# [25] "Van_Dyke_Brown"   "Yellow_Ochre"     "Alizarin_Crimson"

# %%
bob_ross %>% ggplot(aes(x=num_colors)) + geom_density()
# Out:
# plot without title

# %%
bob_ross %>% count(num_colors)
# Out:
#    num_colors n
# 1   1           1
# 2   3           4
# 3   4           4
# 4   5           5
# 5   6          11
# 6   7          25
# 7   8          26
# 8   9          29
# 9  10          44
# 10 11          78
# 11 12         100
# 12 13          58
# 13 14          12
# 14 15           6

# %%
bob_ross %>% filter(num_colors==1) %>% select(img_src, colors)
# Out:
#   img_src                                            colors
# 1 https://www.twoinchbrush.com/images/painting89.png ['Van Dyke Brown']

# %% [markdown]
# ![](https://www.twoinchbrush.com/images/painting89.png)

# %%
write_tsv(bob_ross, "bob_ross.tsv")

# %% [markdown]
# Download all image files on the command line with these commands:
#
# ```bash
# cut -f2,4,5 bob_ross.tsv | perl -ane 'print "wget $F[0] -O $F[1]_$F[2].png\n"' | bash
# mkdir images
# rm season_episode.png
# mv *.png images
# ```
#
# Then continue analysis in `image_analysis_py.ipynb`
